# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("../results/results_42900.csv")
df
# Out:
#     dataset  fold                params                  clf  random_state  \
# 0     42900     0  {'random_state': 42}  logistic_regression            42
# 1     42900     1  {'random_state': 42}  logistic_regression            42
# 2     42900     0  {'random_state': 42}                 qreg            42
# 3     42900     2  {'random_state': 42}  logistic_regression            42
# 4     42900     2  {'random_state': 42}                 qreg            42
# 5     42900     1  {'random_state': 42}                 qreg            42
# 6     42900     3  {'random_state': 42}                 qreg            42
# 7     42900     3  {'random_state': 42}  logistic_regression            42
# 8     42900     5  {'random_state': 42}  logistic_regression            42
# 9     42900     4  {'random_state': 42}  logistic_regression            42
# 10    42900     6  {'random_state': 42}  logistic_regression            42
# ...

# %%
sns.pointplot(df, x="clf", y="test_accuracy", linestyle=" ")
# Out:
# <Axes: xlabel='clf', ylabel='test_accuracy'>
